# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
import matplotlib as mpl

# %%
from tensorflow.keras.datasets import cifar10
(x_train_set, y_train_set), (x_test, y_test)=cifar10.load_data()

# %% [markdown]
# Data

# %%
x_train_set = x_train_set / 255.0
x_test = x_test / 255.0
#讓資料介於0~1之間

# %% [markdown]
# (check data)

# %%
x_train_set.shape, y_train_set.shape, x_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
i = 1
print(y_train_set[i])
plt.imshow(x_train_set[i]) #, cmap='binary')
plt.show()
# Out:
# [9]

# %% [markdown]
# **Split data**

# %%
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(
    x_train_set, y_train_set) #, random_state=1)

# %% [markdown]
# **Stacked Autoencoder**
# 1. Build model

# %%
tf.random.set_seed(1)
np.random.seed(1)

# %%
sk_encoder=keras.models.Sequential([
    keras.layers.Flatten(input_shape=[32,32,3]),
    keras.layers.Dense(100, activation='selu'),
    keras.layers.Dense(30, activation='selu')
])
sk_decoder = keras.models.Sequential([
    keras.layers.Dense(100, activation='selu', input_shape=[30]),
    keras.layers.Dense(32 * 32 * 3, activation='sigmoid'),
    keras.layers.Reshape([32,32,3])
])
sk_ae = keras.models.Sequential([sk_encoder, sk_decoder])

# %%
sk_encoder.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_9 (Flatten)         (None, 3072)              0
#
#  dense_36 (Dense)            (None, 100)               307300
#
#  dense_37 (Dense)            (None, 30)                3030
#
# =================================================================
# Total params: 310,330
# Trainable params: 310,330
# Non-trainable params: 0
# _________________________________________________________________

# %%
sk_decoder.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_38 (Dense)            (None, 100)               3100
#
#  dense_39 (Dense)            (None, 3072)              310272
#
#  reshape_9 (Reshape)         (None, 32, 32, 3)         0
#
# =================================================================
# Total params: 313,372
# Trainable params: 313,372
# Non-trainable params: 0
# _________________________________________________________________

# %%
sk_ae.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_25 (Sequential)  (None, 30)                310330
#
#  sequential_26 (Sequential)  (None, 32, 32, 3)         313372
#
# =================================================================
# Total params: 623,702
# Trainable params: 623,702
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 2. Compile

# %%
def rounded_accuracy(y_true, y_pred):
  return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
sk_ae.compile(loss='binary_crossentropy',
      optimizer = keras.optimizers.SGD(learning_rate=1.5),
      metrics=[rounded_accuracy])

# %% [markdown]
# 3. Train

# %%
train = sk_ae.fit(x_train, x_train,
          epochs=20,
          validation_data=(x_valid, x_valid))
#注意這邊的y_train式放入x_train，是因為這個模型最後產出的值會跟一開始的資料比較。
# Out:
# Epoch 1/20
# 1172/1172 [==============================] - 20s 16ms/step - loss: 0.6447 - rounded_accuracy: 0.7072 - val_loss: 0.6208 - val_rounded_accuracy: 0.7719
# Epoch 2/20
# 1172/1172 [==============================] - 18s 16ms/step - loss: 0.6148 - rounded_accuracy: 0.7870 - val_loss: 0.6105 - val_rounded_accuracy: 0.7919
# Epoch 3/20
# 1172/1172 [==============================] - 20s 17ms/step - loss: 0.6058 - rounded_accuracy: 0.8068 - val_loss: 0.6015 - val_rounded_accuracy: 0.8163
# Epoch 4/20
# 1172/1172 [==============================] - 20s 17ms/step - loss: 0.6002 - rounded_accuracy: 0.8195 - val_loss: 0.6000 - val_rounded_accuracy: 0.8191
# Epoch 5/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5968 - rounded_accuracy: 0.8279 - val_loss: 0.5950 - val_rounded_accuracy: 0.8341
# Epoch 6/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5945 - rounded_accuracy: 0.8335 - val_loss: 0.6008 - val_rounded_accuracy: 0.8203
# Epoch 7/20
# 1172/1172 [==============================] - 18s 16ms/step - loss: 0.5928 - rounded_accuracy: 0.8378 - val_loss: 0.5896 - val_rounded_accuracy: 0.8472
# Epoch 8/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5913 - rounded_accuracy: 0.8413 - val_loss: 0.5895 - val_rounded_accuracy: 0.8487
# Epoch 9/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5904 - rounded_accuracy: 0.8433 - val_loss: 0.5872 - val_rounded_accuracy: 0.8530
# Epoch 10/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5897 - rounded_accuracy: 0.8451 - val_loss: 0.5892 - val_rounded_accuracy: 0.8458
# Epoch 11/20
# 1172/1172 [==============================] - 20s 17ms/step - loss: 0.5890 - rounded_accuracy: 0.8466 - val_loss: 0.5883 - val_rounded_accuracy: 0.8501
# Epoch 12/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5884 - rounded_accuracy: 0.8482 - val_loss: 0.5857 - val_rounded_accuracy: 0.8566
# Epoch 13/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5878 - rounded_accuracy: 0.8495 - val_loss: 0.5863 - val_rounded_accuracy: 0.8549
# Epoch 14/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5874 - rounded_accuracy: 0.8506 - val_loss: 0.5889 - val_rounded_accuracy: 0.8453
# Epoch 15/20
# 1172/1172 [==============================] - 20s 17ms/step - loss: 0.5870 - rounded_accuracy: 0.8513 - val_loss: 0.5867 - val_rounded_accuracy: 0.8528
# Epoch 16/20
# 1172/1172 [==============================] - 20s 17ms/step - loss: 0.5866 - rounded_accuracy: 0.8522 - val_loss: 0.5846 - val_rounded_accuracy: 0.8590
# Epoch 17/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5863 - rounded_accuracy: 0.8531 - val_loss: 0.5857 - val_rounded_accuracy: 0.8550
# Epoch 18/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5861 - rounded_accuracy: 0.8537 - val_loss: 0.5868 - val_rounded_accuracy: 0.8543
# Epoch 19/20
# 1172/1172 [==============================] - 20s 17ms/step - loss: 0.5860 - rounded_accuracy: 0.8539 - val_loss: 0.5851 - val_rounded_accuracy: 0.8569
# Epoch 20/20
# 1172/1172 [==============================] - 19s 16ms/step - loss: 0.5858 - rounded_accuracy: 0.8543 - val_loss: 0.5843 - val_rounded_accuracy: 0.8602

# %%
pd.DataFrame(train.history).plot()
plt.grid(True)
plt.show()

# %% [markdown]
# 4.Evaluate

# %%
sk_ae.evaluate(x_test, x_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.5849 - rounded_accuracy: 0.8592
# [0.5848637819290161, 0.8591726422309875]

# %% [markdown]
# 5. Predict(Reconstruct)

# %%
x_test_decoded = sk_ae.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step

# %%
plt.figure(figsize=(10,4))
for i in range(5):
  plt.subplot(2, 5, 1+i)
  plt.imshow(x_test[i], cmap='binary')
  plt.title('orginal')
  plt.axis('off')

  '''plt.subplot(2, 5, 1+5+i)
  plt.imshow(x_test_decoded[i], cmap='binary')
  plt.title('reconstructed')
  plt.axis('off')'''
plt.show()

# %% [markdown]
# (Check codings)

# %%
x_test_codings = sk_encoder.predict(x_test)
x_test_codings.shape
# Out:
# 313/313 [==============================] - 1s 2ms/step
# (10000, 30)

# %%
i = range(5)

plt.imshow(x_test_codings[i], cmap='binary')
plt.axis('off')
plt.show()

# %% [markdown]
# **Application: Data Visualization**

# %%
#視覺化降維
from sklearn.manifold import TSNE

np.random.seed(1)

tsne = TSNE()
x_test_2D = tsne.fit_transform(x_test_codings)

x_test_2D = (x_test_2D - x_test_2D.min()) / (x_test_2D.max()-x_test_2D.min())
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
x_test_2D.shape
# Out:
# (10000, 2)

# %%
plt.figure(figsize=(10,8))
scatter = plt.scatter(x_test_2D[:,0], x_test_2D[:,1], c=y_test, s=10,
            cmap=plt.cm.tab10)
#c是color，表示用y_test的資料上色；s是點的大小。
plt.legend(*scatter.legend_elements())
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.scatter(x_test_2D[:,0], x_test_2D[:,1], c=y_test, s=10, cmap=plt.cm.tab10)
plt.axis('off')

image_positions = np.array([[1.,1.]])
for index, position in enumerate(x_test_2D):
  dist = np.sum((position - image_positions) ** 2, axis=1)
  if np.min(dist) > 0.02:
    image_positions = np.r_[image_positions, [position]]
    imagebox = mpl.offsetbox.AnnotationBbox(
        mpl.offsetbox.OffsetImage(x_test[index], cmap='binary'),
        position,
        bboxprops={'edgecolor':plt.cm.tab10(y_test[index]), 'lw':2})
    plt.gca().add_artist(imagebox)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-e90b0ab1827b> in <module>
#       8   if np.min(dist) > 0.02:
#       9     image_positions = np.r_[image_positions, [position]]
# ---> 10     imagebox = mpl.offsetbox.AnnotationBbox(
#      11         mpl.offsetbox.OffsetImage(x_test[index], cmap='binary'),
#      12         position,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/offsetbox.py in __init__(self, offsetbox, xy, xybox, xycoords, boxcoords, frameon, pad, annotation_clip, box_alignment, bboxprops, arrowprops, fontsize, **kwargs)
#    1503         self.patch.set_boxstyle("square", pad=pad)
#    1504         if bboxprops:
# -> 1505             self.patch.set(**bboxprops)
#    1506         self._drawFrame = frameon
#    1507
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in set(self, **kwargs)
#    1099             sorted(kwargs.items(), reverse=True,
#    1100                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
# -> 1101         return self.update(props)
#    1102
#    1103     def findobj(self, match=None, include_self=True):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
# -> 1003                 return func(v)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in set_edgecolor(self, color)
#     337         """
#     338         self._original_edgecolor = color
# --> 339         self._set_edgecolor(color)
#     340
#     341     def _set_facecolor(self, color):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in _set_edgecolor(self, color)
#     323                 set_hatch_color = False
#     324
# --> 325         self._edgecolor = colors.to_rgba(color, self._alpha)
#     326         if set_hatch_color:
#     327             self._hatch_color = self._edgecolor
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     183         rgba = None
#     184     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 185         rgba = _to_rgba_no_colorcycle(c, alpha)
#     186         try:
#     187             _colors_full_map.cache[c, alpha] = rgba
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     266         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     267         # Test dimensionality to reject single floats.
# --> 268         raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     269     # Return a tuple to prevent the cached value from being modified.
#     270     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: array([[0.83921569, 0.15294118, 0.15686275, 1.        ]])
